# %% [markdown]
# Primera Actividad de Laboratorio (Procesando Imágenes)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def imageManager(img_name,axis):
    image=cv2.imread(img_name)
    plt.imshow(image)
    plt.axis(axis)
    plt.show()

    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.axis(axis)
    plt.show()

    grayImage=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite('grayImage.jpg',grayImage)
    #plt.imshow(grayImage)
    plt.imshow(grayImage, cmap='gray')
    plt.axis(axis)
    plt.show()

imageManager('WIN_20240229_19_22_48_Pro.JPG','off')
