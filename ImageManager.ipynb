# %% [markdown]
# Opening An Image

# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage
from skimage import feature
import numpy as np
import scipy.misc
import scipy

# %%
def open_img(img):
    route=("C:/Proyectos Univalle/Procesamiento Digital de Imágenes/ImageSources/" +img)
    img = Image.open(route)
    img.show()
open_img("WIN_20240229_19_22_48_Pro.JPG")

# %% [markdown]
# Open an image with Jupyter

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize']=[10,5]

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("WIN_20240229_19_22_48_Pro.JPG")
print("Image Size: ",img.shape)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Image Size:  (720, 1280, 3)

# %%
image=cv2.imread("WIN_20240229_19_22_48_Pro.JPG", cv2.IMREAD_COLOR)
plt.figure()

plt.subplot(141) #Matriz de una fila, 3 items y que empieza en 1
plt.title('Original')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(142)
plt.title('Red Channel')
plt.imshow(image[:,:,0])
plt.axis('off')

plt.subplot(143)
plt.title('Green Channel')
plt.imshow(image[:,:,1],cmap='Reds')
plt.axis('off')

plt.subplot(144)
plt.title('Blue Channel')
plt.imshow(image[:,:,2],cmap='Blues')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread("WIN_20240229_19_22_48_Pro.JPG", cv2.IMREAD_GRAYSCALE)
original_img = image.dtype # Guardamos la profundidad original de nuestra imagen.
print("Profundidad original de color")
img_16bits = np.uint16(image) #Transformamos nuestra imagen a 16 Bits
new_img = img_16bits.dtype
print("Profundidad de color nueva")
cv2.imwrite('new_img.jpg',img_16bits)
img_saved = cv2.imread('new_img.jpg', cv2.IMREAD_UNCHANGED)
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.title('Image Original')
plt.imshow(image, cmap='gray')

plt.subplot(122)
plt.title('Image Changed')
plt.imshow(img_saved, cmap='gray')
# Out:
# Profundidad original de color
# Profundidad de color nueva

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [6,3]

imgInicialRgb = cv2.imread('WIN_20240229_19_22_48_Pro.JPG')
print(imgInicialRgb.shape)
plt.imshow(cv2.cvtColor(imgInicialRgb, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

imagenRGB = plt.imread('WIN_20240229_19_22_48_Pro.JPG')
print(imagenRGB)
plt.imshow(imagenRGB)
plt.axis('off')
plt.show
# Out:
# (720, 1280, 3)
# [[[255 253 255]
#   [255 253 255]
#   [255 253 255]
#   ...
#   [172 155 147]
#   [172 155 147]
#   [171 154 146]]
#
#  [[255 253 255]
#   [255 253 255]
#   [255 253 255]
#   ...
#   [172 155 147]
#   [171 154 146]
#   [170 153 145]]
#
#  [[255 253 255]
#   [255 253 255]
#   [255 253 255]
#   ...
#   [172 155 147]
#   [172 155 147]
#   [172 155 147]]
#
#  ...
#
#  [[131 116 111]
#   [132 117 112]
#   [129 114 111]
#   ...
#   [128 107  88]
#   [126 108  88]
#   [126 108  88]]
#
#  [[125 106 108]
#   [125 109 110]
#   [123 107 110]
#   ...
#   [126 108  88]
#   [126 108  88]
#   [126 108  88]]
#
#  [[106  87  93]
#   [110  93  99]
#   [113  96 102]
#   ...
#   [125 107  87]
#   [126 108  88]
#   [126 108  88]]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Primera Actividad con Procesamiento de Imágenes
