# %% [markdown]
# Ecualización de Histograma

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_gray = cv2.imread('Shar2.jpg', cv2.IMREAD_GRAYSCALE)

histogram,_ = np.histogram(img_gray.flatten(),256,[0,256])
function_distrib=histogram.cumsum()
histo_normalized= function_distrib*histogram.max()/function_distrib.max()    #resultante de la función integral
histo_equalized=cv2.equalizeHist(img_gray)

plt.figure(figsize=(12, 9))

plt.subplot(221)
plt.imshow(img_gray,cmap="gray")
plt.title("Imagen Original")

plt.subplot(222)
plt.plot(histogram, color = "purple")
plt.title('HISTOGRAMA')
plt.xlabel('Intensidad de pixel')
plt.ylabel('Frecuencia')

plt.subplot(223)
plt.plot(histo_normalized, color = "purple")
plt.title('HISTOGRAMA NORMALIZADO')
plt.xlabel('Intensidad de pixel')
plt.ylabel('Frecuencia')

plt.subplot(224)
plt.plot(histo_equalized, color = "purple")
plt.title('HISTOGRAMA EQUALIZADO')
plt.xlabel('Intensidad de pixel')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Algoritmo de Clahe

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_gray = cv2.imread('Shar2.jpg', cv2.IMREAD_GRAYSCALE)
clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(9,9))
new_img=clahe.apply(img_gray)

histogram,_ = np.histogram(img_gray.flatten(),256,[0,256])
histogram2,__ = np.histogram(new_img.flatten(),256,[0,256])

plt.figure(figsize=(12, 9))

plt.subplot(221)
plt.imshow(img_gray,cmap="gray")
plt.title("Imagen Original")

plt.subplot(222)
plt.imshow(new_img,cmap="gray")
plt.title("Imagen Equalizada")

plt.subplot(223)
plt.plot(histogram, color = "purple")
plt.title('HISTOGRAMA')
plt.xlabel('Intensidad de pixel')
plt.ylabel('Frecuencia')

plt.subplot(224)
plt.plot(histogram2, color = "purple")
plt.title('HISTOGRAMA EQUALIZADO')
plt.xlabel('Intensidad de pixel')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Clahe para imágenes a color

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('Shar2.jpg')

#img = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)

#img_gray = cv2.imread('Shar2.jpg', cv2.IMREAD_GRAYSCALE)


# color = ('r','g','b')
# for canal, col in enumerate(color):
#     histogram_cancer = cv2.calcHist([celula_cancer_img*255],[canal],None,[256],[0,256]) #Histograma
#     plt.plot(histogram_cancer,color=col)
#     plt.xlim([0,256])
# plt.show()

#blue=img[:,:,0]*255
#red=img[:,:,1]*255
#green=img[:,:,2]*255

blue, red, green =cv2.split(img)

clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(9,9))

new_img_b=clahe.apply(blue)
new_img_r=clahe.apply(red)
new_img_g=clahe.apply(green)

new_final_img=cv2.merge((new_img_b,new_img_r,new_img_g))  #OJO. EL ORDEN ES BLUE, RED, GREEN


#new_final_img = np.array(new_img_r*new_img_g*new_img_b*255,dtype=int) #Armamos la matriz

# histogram,_ = np.histogram(img_gray.flatten(),256,[0,256])
# histogram2,__ = np.histogram(new_img.flatten(),256,[0,256])

# histogram_cancer = cv2.calcHist([celula_cancer_img*255],[canal],None,[256],[0,256]) #Histograma
# plt.plot(histogram_cancer,color=col)
# plt.xlim([0,256])
# plt.show()



plt.figure(figsize=(12, 9))

plt.subplot(221)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Imagen Original Color")

plt.subplot(222)
plt.imshow(cv2.cvtColor(new_final_img, cv2.COLOR_BGR2RGB))
plt.title("Imagen Equalizada Color")

# plt.subplot(223)
# plt.plot(histogram, color = "purple")
# plt.title('HISTOGRAMA')
# plt.xlabel('Intensidad de pixel')
# plt.ylabel('Frecuencia')

# plt.subplot(224)
# plt.plot(histogram2, color = "purple")
# plt.title('HISTOGRAMA EQUALIZADO')
# plt.xlabel('Intensidad de pixel')
# plt.ylabel('Frecuencia')
# Out:
# Text(0.5, 1.0, 'Imagen Equalizada Color')
